# %%
import pandas as pd
import numpy as np

df = pd.read_csv("../data/MetroPT3(AirCompressor).csv")
print(df.shape)
print(df.columns.tolist())
df.head()
# Out:
# (1516948, 17)
# ['Unnamed: 0', 'timestamp', 'TP2', 'TP3', 'H1', 'DV_pressure', 'Reservoirs', 'Oil_temperature', 'Motor_current', 'COMP', 'DV_eletric', 'Towers', 'MPG', 'LPS', 'Pressure_switch', 'Oil_level', 'Caudal_impulses']
#    Unnamed: 0            timestamp    TP2    TP3     H1  DV_pressure  \
# 0           0  2020-02-01 00:00:00 -0.012  9.358  9.340       -0.024
# 1          10  2020-02-01 00:00:10 -0.014  9.348  9.332       -0.022
# 2          20  2020-02-01 00:00:19 -0.012  9.338  9.322       -0.022
# 3          30  2020-02-01 00:00:29 -0.012  9.328  9.312       -0.022
# 4          40  2020-02-01 00:00:39 -0.012  9.318  9.302       -0.022
#
#    Reservoirs  Oil_temperature  Motor_current  COMP  DV_eletric  Towers  MPG  \
# 0       9.358           53.600         0.0400   1.0         0.0     1.0  1.0
# 1       9.348           53.675         0.0400   1.0         0.0     1.0  1.0
# 2       9.338           53.600         0.0425   1.0         0.0     1.0  1.0
# ...

# %%
df = df.drop(columns=['Unnamed: 0'])
df['timestamp'] = pd.to_datetime(df['timestamp'])
print(df['timestamp'].min(), df['timestamp'].max())
# Out:
# 2020-02-01 00:00:00 2020-09-01 03:59:50

# %%
df.isnull().sum()
# Out:
# timestamp          0
# TP2                0
# TP3                0
# H1                 0
# DV_pressure        0
# Reservoirs         0
# Oil_temperature    0
# Motor_current      0
# COMP               0
# DV_eletric         0
# Towers             0
# MPG                0
# LPS                0
# Pressure_switch    0
# Oil_level          0
# Caudal_impulses    0
# dtype: int64

# %%
continuous_cols = ['TP2','TP3','H1','DV_pressure','Reservoirs','Oil_temperature','Motor_current']
df[continuous_cols].describe()
# Out:
#                 TP2           TP3            H1   DV_pressure    Reservoirs  \
# count  1.516948e+06  1.516948e+06  1.516948e+06  1.516948e+06  1.516948e+06
# mean   1.367826e+00  8.984611e+00  7.568155e+00  5.595619e-02  8.985233e+00
# std    3.250930e+00  6.390951e-01  3.333200e+00  3.824015e-01  6.383070e-01
# min   -3.200000e-02  7.300000e-01 -3.600000e-02 -3.200000e-02  7.120000e-01
# 25%   -1.400000e-02  8.492000e+00  8.254000e+00 -2.200000e-02  8.494000e+00
# 50%   -1.200000e-02  8.960000e+00  8.784000e+00 -2.000000e-02  8.960000e+00
# 75%   -1.000000e-02  9.492000e+00  9.374000e+00 -1.800000e-02  9.492000e+00
# max    1.067600e+01  1.030200e+01  1.028800e+01  9.844000e+00  1.030000e+01
#
#        Oil_temperature  Motor_current
# count     1.516948e+06   1.516948e+06
# mean      6.264418e+01   2.050171e+00
# std       6.516261e+00   2.302053e+00
# min       1.540000e+01   2.000000e-02
# 25%       5.777500e+01   4.000000e-02
# 50%       6.270000e+01   4.500000e-02
# ...

# %%
digital_cols = ['COMP','DV_eletric','Towers','MPG','LPS','Pressure_switch','Oil_level','Caudal_impulses']
for col in digital_cols:
    print(col, df[col].value_counts())
# Out:
# COMP COMP
# 1.0    1269620
# 0.0     247328
# Name: count, dtype: int64
# DV_eletric DV_eletric
# 0.0    1273310
# 1.0     243638
# Name: count, dtype: int64
# Towers Towers
# 1.0    1395362
# 0.0     121586
# Name: count, dtype: int64
# MPG MPG
# 1.0    1263108
# 0.0     253840
# Name: count, dtype: int64
# LPS LPS
# 0.0    1511760
# 1.0       5188
# Name: count, dtype: int64
# Pressure_switch Pressure_switch
# 1.0    1503958
# 0.0      12990
# Name: count, dtype: int64
# Oil_level Oil_level
# 1.0    1371557
# 0.0     145391
# Name: count, dtype: int64
# Caudal_impulses Caudal_impulses
# 1.0    1421542
# 0.0      95406
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(4, 1, figsize=(18, 12), sharex=True)
axes[0].plot(df['timestamp'], df['TP2'])
axes[0].set_ylabel('TP2')
axes[1].plot(df['timestamp'], df['Oil_temperature'])
axes[1].set_ylabel('Oil_temperature')
axes[2].plot(df['timestamp'], df['Motor_current'])
axes[2].set_ylabel('Motor_current')
axes[3].plot(df['timestamp'], df['Reservoirs'])
axes[3].set_ylabel('Reservoirs')
plt.tight_layout()
plt.savefig('sensor_overview.png', dpi=100)

# %%
df_hourly = df.set_index('timestamp').resample('1h').mean().reset_index()

# %%
failures = [
    ('2020-04-18 00:00', '2020-04-18 23:59', 'Failure 1'),
    ('2020-05-29 23:30', '2020-05-30 06:00', 'Failure 2'),
    ('2020-06-05 10:00', '2020-06-07 14:30', 'Failure 3'),
    ('2020-07-15 14:30', '2020-07-15 19:00', 'Failure 4'),
]

df['label'] = 0
for start, end, name in failures:
    mask = (df['timestamp'] >= start) & (df['timestamp'] <= end)
    df.loc[mask, 'label'] = 1

print(df['label'].value_counts())

# %%
sensors = ['TP2','TP3','H1','DV_pressure','Reservoirs','Oil_temperature','Motor_current']

for start, end, name in failures:
    start_ts = pd.Timestamp(start) - pd.Timedelta(hours=6)
    end_ts = pd.Timestamp(end) + pd.Timedelta(hours=6)
    window = df[(df['timestamp'] >= start_ts) & (df['timestamp'] <= end_ts)]

    fig, axes = plt.subplots(len(sensors), 1, figsize=(16, 14), sharex=True)
    for i, s in enumerate(sensors):
        axes[i].plot(window['timestamp'], window[s])
        axes[i].axvspan(pd.Timestamp(start), pd.Timestamp(end), color='red', alpha=0.2)
        axes[i].set_ylabel(s)
    axes[0].set_title(name)
    plt.tight_layout()
    plt.savefig(f'{name.replace(" ","_")}.png', dpi=100)
    plt.close()
    print(f"Saved {name.replace(' ','_')}.png")

# %%
summary_rows = []
for start, end, name in failures:
    fail_window = df[(df['timestamp'] >= start) & (df['timestamp'] <= end)]
    before_window = df[(df['timestamp'] >= pd.Timestamp(start) - pd.Timedelta(hours=6)) &
                        (df['timestamp'] < start)]
    for s in sensors:
        b_mean, b_std = before_window[s].mean(), before_window[s].std()
        d_mean = fail_window[s].mean()
        # z-score style shift: how many "normal std devs" did the mean move?
        shift = (d_mean - b_mean) / b_std if b_std > 0 else float('nan')
        summary_rows.append({'failure': name, 'sensor': s, 'before_mean': round(b_mean,3),
                              'during_mean': round(d_mean,3), 'before_std': round(b_std,3),
                              'shift_in_stds': round(shift,2)})

summary_df = pd.DataFrame(summary_rows)
print(summary_df.to_string(index=False))
summary_df.to_csv('failure_sensor_summary.csv', index=False)

# %%
window = 60  # ~10 minutes at 10s sampling — adjust after seeing results

sensors = ['TP2','TP3','H1','DV_pressure','Reservoirs','Oil_temperature','Motor_current']

df = df.sort_values('timestamp').reset_index(drop=True)

for s in sensors:
    df[f'{s}_roll_std'] = df[s].rolling(window, min_periods=1).std()
    df[f'{s}_roll_range'] = (df[s].rolling(window, min_periods=1).max()
                              - df[s].rolling(window, min_periods=1).min())
    df[f'{s}_roll_mean'] = df[s].rolling(window, min_periods=1).mean()

# %%
# Count how many times H1 crosses a low threshold within the rolling window
# (proxy for "is the compressor still cutting off normally")
threshold = 1.0
df['H1_low'] = (df['H1'] < threshold).astype(int)
df['H1_cycle_transitions'] = df['H1_low'].diff().abs().rolling(window, min_periods=1).sum()

# %%
for s in ['Oil_temperature','Motor_current','TP3','Reservoirs']:
    df[f'{s}_diff'] = df[s].diff()
    df[f'{s}_roll_trend'] = df[s].rolling(window, min_periods=1).mean().diff()

# %%
check_cols = ['H1_roll_std','H1_cycle_transitions','Oil_temperature_roll_trend']
sample_fail = df[(df['timestamp'] >= '2020-06-05 10:00') & (df['timestamp'] <= '2020-06-07 14:30')]
sample_normal = df[(df['timestamp'] >= '2020-06-01 00:00') & (df['timestamp'] <= '2020-06-01 06:00')]

print("FAILURE window:\n", sample_fail[check_cols].describe())
print("\nNORMAL window:\n", sample_normal[check_cols].describe())

# %%
check_cols = ['H1_roll_std', 'H1_cycle_transitions']

failure_windows = [
    ('2020-04-18 00:00', '2020-04-18 23:59', 'Failure 1'),
    ('2020-05-29 23:30', '2020-05-30 06:00', 'Failure 2'),
    ('2020-06-05 10:00', '2020-06-07 14:30', 'Failure 3'),
    ('2020-07-15 14:30', '2020-07-15 19:00', 'Failure 4'),
]

# Use a verified-active normal window for each (a few days before each failure,
# picked to avoid idle periods)
normal_windows = [
    ('2020-04-15 00:00', '2020-04-15 06:00'),
    ('2020-05-26 00:00', '2020-05-26 06:00'),
    ('2020-06-01 00:00', '2020-06-01 06:00'),
    ('2020-07-12 00:00', '2020-07-12 06:00'),
]

for (f_start, f_end, name), (n_start, n_end) in zip(failure_windows, normal_windows):
    fail = df[(df['timestamp'] >= f_start) & (df['timestamp'] <= f_end)]
    normal = df[(df['timestamp'] >= n_start) & (df['timestamp'] <= n_end)]
    
    print(f"\n=== {name} ===")
    print("Normal H1_roll_std mean:", round(normal['H1_roll_std'].mean(), 4),
          "| H1_cycle_transitions mean:", round(normal['H1_cycle_transitions'].mean(), 4))
    print("Failure H1_roll_std mean:", round(fail['H1_roll_std'].mean(), 4),
          "| H1_cycle_transitions mean:", round(fail['H1_cycle_transitions'].mean(), 4))

# %%
df = df.sort_values('timestamp').reset_index(drop=True)

split_date = '2020-07-01'

train = df[df['timestamp'] < split_date].copy()
test = df[df['timestamp'] >= split_date].copy()

print("Train:", train.shape, "| failures:", train['label'].sum())
print("Test:", test.shape, "| failures:", test['label'].sum())

# %%
from sklearn.ensemble import IsolationForest

feature_cols = [
    'H1_roll_std', 'H1_cycle_transitions',
    'TP2_roll_std', 'TP2_roll_range',
    'TP3_roll_std', 'TP3_roll_range',
    'Reservoirs_roll_std', 'Reservoirs_roll_range',
    'Oil_temperature_roll_mean', 'Oil_temperature_roll_trend',
    'Motor_current_roll_std', 'Motor_current_roll_range',
]

# Train only on NORMAL data (label == 0) — this is standard practice for
# anomaly detection: the model should learn what "normal" looks like,
# not be shown failures during training
X_train = train[train['label'] == 0][feature_cols].dropna()
X_test = test[feature_cols].dropna()
y_test = test.loc[X_test.index, 'label']

model = IsolationForest(
    n_estimators=200,
    contamination=0.02,  # matches our known ~2% failure rate
    random_state=42,
    n_jobs=-1
)
model.fit(X_train)

print("Model trained on", X_train.shape[0], "normal rows")

# %%
fail4_check = df[(df['timestamp'] >= '2020-07-15 14:30') & (df['timestamp'] <= '2020-07-15 19:00')]
print(len(fail4_check))

# %%
from sklearn.metrics import classification_report, confusion_matrix

preds = model.predict(X_test)
preds_binary = (preds == -1).astype(int)

print(confusion_matrix(y_test, preds_binary))
print(classification_report(y_test, preds_binary))

# %%
fail4_test = test[(test['timestamp'] >= '2020-07-15 14:30') & (test['timestamp'] <= '2020-07-15 19:00')]
fail4_X = fail4_test[feature_cols].dropna()
fail4_preds = model.predict(fail4_X)
print("Failure 4 rows flagged as anomaly:", (fail4_preds == -1).sum(), "out of", len(fail4_preds))

# %%
model_v2 = IsolationForest(n_estimators=200, contamination=0.005, random_state=42, n_jobs=-1)
model_v2.fit(X_train)
preds_v2 = model_v2.predict(X_test)
preds_v2_binary = (preds_v2 == -1).astype(int)
print(classification_report(y_test, preds_v2_binary))

# %%
scores = model.decision_function(X_test)  # lower = more anomalous
# Try different percentile thresholds
import numpy as np
for pct in [1, 2, 3, 5]:
    threshold = np.percentile(scores, pct)
    preds_custom = (scores < threshold).astype(int)
    print(f"\n--- Threshold at {pct}th percentile ---")
    print(classification_report(y_test, preds_custom))

# %%
import numpy as np

# Get anomaly scores for the full test set (lower = more anomalous)
test_scores = model.decision_function(X_test)

# Use the 5th percentile threshold from before
threshold_5pct = np.percentile(test_scores, 5)
raw_flags = (test_scores < threshold_5pct).astype(int)

# Build a temporary dataframe aligned with X_test's index to work with rolling windows
flag_df = test.loc[X_test.index, ['timestamp', 'label']].copy()
flag_df['raw_flag'] = raw_flags

# Sort by time (should already be sorted, but confirm)
flag_df = flag_df.sort_values('timestamp').reset_index(drop=True)

# Persistence rule: flag only if at least 50% of the last 60 rows (~10 min) were also flagged
persistence_window = 60
flag_df['flag_rate'] = flag_df['raw_flag'].rolling(persistence_window, min_periods=1).mean()
flag_df['smoothed_flag'] = (flag_df['flag_rate'] >= 0.5).astype(int)

print(classification_report(flag_df['label'], flag_df['smoothed_flag']))

# %%
import joblib

# Save the trained model
joblib.dump(model, 'models/isolation_forest_v1.pkl')

# Save the processed dataframe with features + labels, so you don't have to rebuild it
df.to_csv('data/df_processed.csv', index=False)

print("Model and data saved")

# %%
# For each flagged row, compare its feature values against normal ranges
normal_stats = X_train[feature_cols].agg(['mean', 'std']).T
normal_stats.columns = ['normal_mean', 'normal_std']

def explain_alert(row, normal_stats, top_n=3):
    """Given a flagged row's features, return the top N most deviating features."""
    deviations = {}
    for feat in feature_cols:
        val = row[feat]
        mean = normal_stats.loc[feat, 'normal_mean']
        std = normal_stats.loc[feat, 'normal_std']
        if std > 0:
            z = abs((val - mean) / std)
            deviations[feat] = z
    top_features = sorted(deviations.items(), key=lambda x: -x[1])[:top_n]
    return top_features

# Test it on one flagged row from Failure 4
example_row = fail4_test[feature_cols].dropna().iloc[0]
explanation = explain_alert(example_row, normal_stats)
print("Top contributing features for this alert:")
for feat, z in explanation:
    print(f"  {feat}: {z:.2f} standard deviations from normal")

# %%
def classify_severity(top_features, flag_rate):
    """Simple rule: map deviation magnitude + persistence to an action recommendation."""
    max_z = top_features[0][1]
    if flag_rate >= 0.8 and max_z > 3:
        return "ESCALATE"
    elif flag_rate >= 0.5 and max_z > 1.5:
        return "INVESTIGATE"
    else:
        return "MONITOR"

def generate_alert_report(row, normal_stats, flag_rate, top_n=3):
    top_features = explain_alert(row, normal_stats, top_n)
    severity = classify_severity(top_features, flag_rate)
    report = {
        'severity': severity,
        'top_features': top_features,
        'flag_rate': flag_rate,
    }
    return report

# Test on the same example, assuming its flag_rate from the smoothed df
example_flag_rate = flag_df.loc[flag_df['timestamp'] == fail4_test.iloc[0]['timestamp'], 'flag_rate'].values[0]
report = generate_alert_report(example_row, normal_stats, example_flag_rate)
print(report)

# %%
# Apply the full pipeline to ALL flagged rows in Failure 4, not just one
fail4_flagged = flag_df[(flag_df['timestamp'] >= '2020-07-15 14:30') &
                         (flag_df['timestamp'] <= '2020-07-15 19:00') &
                         (flag_df['smoothed_flag'] == 1)]

severities = []
for idx, frow in fail4_flagged.iterrows():
    test_row = test.loc[test['timestamp'] == frow['timestamp'], feature_cols]
    if len(test_row) == 0:
        continue
    row_data = test_row.iloc[0]
    top_feats = explain_alert(row_data, normal_stats)
    sev = classify_severity(top_feats, frow['flag_rate'])
    severities.append(sev)

from collections import Counter
print(Counter(severities))

# %%
import joblib
import pandas as pd
import numpy as np

class CompressorAnomalyPipeline:
    def __init__(self, model, normal_stats, feature_cols, 
                 threshold_percentile=5, persistence_window=60, persistence_ratio=0.5):
        self.model = model
        self.normal_stats = normal_stats
        self.feature_cols = feature_cols
        self.threshold_percentile = threshold_percentile
        self.persistence_window = persistence_window
        self.persistence_ratio = persistence_ratio
        self.threshold_ = None  # set during fit_threshold or passed in

    def set_threshold(self, reference_scores):
        """Call once on a reference/validation set to lock in the anomaly threshold."""
        self.threshold_ = np.percentile(reference_scores, self.threshold_percentile)

    def score(self, X):
        """Raw anomaly scores — lower = more anomalous."""
        return self.model.decision_function(X[self.feature_cols])

    def detect(self, df_chunk):
        """
        Run the full pipeline on a chunk of data with a 'timestamp' column
        and all feature_cols present. Returns df_chunk with added columns:
        raw_flag, flag_rate, smoothed_flag.
        """
        df_chunk = df_chunk.sort_values('timestamp').reset_index(drop=True)
        scores = self.score(df_chunk)
        df_chunk['raw_flag'] = (scores < self.threshold_).astype(int)
        df_chunk['flag_rate'] = df_chunk['raw_flag'].rolling(
            self.persistence_window, min_periods=1).mean()
        df_chunk['smoothed_flag'] = (df_chunk['flag_rate'] >= self.persistence_ratio).astype(int)
        return df_chunk

    def explain(self, row, top_n=3):
        deviations = {}
        for feat in self.feature_cols:
            val = row[feat]
            mean = self.normal_stats.loc[feat, 'normal_mean']
            std = self.normal_stats.loc[feat, 'normal_std']
            if std > 0:
                deviations[feat] = abs((val - mean) / std)
        return sorted(deviations.items(), key=lambda x: -x[1])[:top_n]

    def classify_severity(self, top_features, flag_rate):
        max_z = top_features[0][1]
        if max_z >= 3.2:
            return "ESCALATE"
        elif max_z >= 2.0:
            return "INVESTIGATE"
        else:
            return "MONITOR"
            
    def run(self, df_chunk):
        """Full pipeline: detect -> for each smoothed-flagged row, explain + classify."""
        detected = self.detect(df_chunk)
        alerts = []
        flagged_rows = detected[detected['smoothed_flag'] == 1]
        for idx, frow in flagged_rows.iterrows():
            top_feats = self.explain(frow)
            severity = self.classify_severity(top_feats, frow['flag_rate'])
            alerts.append({
                'timestamp': frow['timestamp'],
                'severity': severity,
                'top_features': top_feats,
                'flag_rate': frow['flag_rate']
            })
        return pd.DataFrame(alerts)

# %%
pipeline = CompressorAnomalyPipeline(model, normal_stats, feature_cols)
pipeline.set_threshold(test_scores)  # test_scores from earlier decision_function call

fail4_chunk = test[(test['timestamp'] >= '2020-07-15 08:00') & 
                    (test['timestamp'] <= '2020-07-16 02:00')].copy()

alerts = pipeline.run(fail4_chunk)
print(alerts['severity'].value_counts())
print(alerts.head())

# %%
joblib.dump(pipeline, 'models/compressor_pipeline_v1.pkl')

# %%
# Restrict pipeline output to just the actual failure window, for a fair comparison
alerts['timestamp'] = pd.to_datetime(alerts['timestamp'])
fail_only = alerts[(alerts['timestamp'] >= '2020-07-15 14:30') & (alerts['timestamp'] <= '2020-07-15 19:00')]
print(fail_only['severity'].value_counts())
print("Total alerts in failure window:", len(fail_only))

# %%
failure_ranges = [
    ('2020-04-17 18:00', '2020-04-19 06:00', 'Failure 1'),
    ('2020-05-29 17:30', '2020-05-30 12:00', 'Failure 2'),
    ('2020-06-05 04:00', '2020-06-07 20:30', 'Failure 3'),
]

for start, end, name in failure_ranges:
    chunk = df[(df['timestamp'] >= start) & (df['timestamp'] <= end)].copy()
    alerts = pipeline.run(chunk)
    
    # Restrict to just the actual failure window for a clean comparison
    exact_windows = {
        'Failure 1': ('2020-04-18 00:00', '2020-04-18 23:59'),
        'Failure 2': ('2020-05-29 23:30', '2020-05-30 06:00'),
        'Failure 3': ('2020-06-05 10:00', '2020-06-07 14:30'),
    }
    f_start, f_end = exact_windows[name]
    alerts['timestamp'] = pd.to_datetime(alerts['timestamp'])
    fail_only = alerts[(alerts['timestamp'] >= f_start) & (alerts['timestamp'] <= f_end)]
    
    print(f"\n=== {name} ===")
    print(fail_only['severity'].value_counts())
    print("Total alerts in failure window:", len(fail_only))

# %%
# Run the pipeline on the full test set to see the natural distribution of severity inputs
all_test_alerts = pipeline.detect(test.copy())
flagged = all_test_alerts[all_test_alerts['smoothed_flag'] == 1].copy()

max_zs = []
for idx, frow in flagged.iterrows():
    top_feats = pipeline.explain(frow)
    max_zs.append(top_feats[0][1])
flagged['max_z'] = max_zs

print(flagged[['flag_rate', 'max_z']].describe())
print("\nPercentiles of max_z:")
print(flagged['max_z'].quantile([0.25, 0.5, 0.75, 0.9]))

# %%
# Check: during real failures, how many of the top features are consistently anomalous
# vs during false positives?

# First, let's isolate the false positives from our earlier smoothed predictions
flag_df_test = flag_df.copy()  # from earlier: has timestamp, label, smoothed_flag
false_positives = flag_df_test[(flag_df_test['smoothed_flag'] == 1) & (flag_df_test['label'] == 0)]
true_positives = flag_df_test[(flag_df_test['smoothed_flag'] == 1) & (flag_df_test['label'] == 1)]

print("False positives:", len(false_positives))
print("True positives:", len(true_positives))

# Sample a few false positive timestamps and check their feature deviations
sample_fp_times = false_positives['timestamp'].sample(min(5, len(false_positives)), random_state=42)
for t in sample_fp_times:
    row = test[test['timestamp'] == t][feature_cols]
    if len(row) == 0:
        continue
    top_feats = pipeline.explain(row.iloc[0])
    print(f"{t}: {top_feats}")

# %%
# Check timing of false positives relative to the 4 known failures
known_failures = [
    ('2020-04-18 00:00', '2020-04-18 23:59'),
    ('2020-05-29 23:30', '2020-05-30 06:00'),
    ('2020-06-05 10:00', '2020-06-07 14:30'),
    ('2020-07-15 14:30', '2020-07-15 19:00'),
]

def hours_to_nearest_failure(ts):
    diffs = [min(abs((ts - pd.Timestamp(s)).total_seconds()),
                 abs((ts - pd.Timestamp(e)).total_seconds())) for s, e in known_failures]
    return min(diffs) / 3600

false_positives['hours_to_failure'] = false_positives['timestamp'].apply(hours_to_nearest_failure)
print(false_positives['hours_to_failure'].describe())
print("\nFalse positives within 24hrs of a known failure:", (false_positives['hours_to_failure'] <= 24).sum())
print("False positives within 6hrs of a known failure:", (false_positives['hours_to_failure'] <= 6).sum())
